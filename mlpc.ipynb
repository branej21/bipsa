# %%
import numpy as np 
import pandas as pd 



import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
directory="/kaggle/input/food-nutrition-dataset/FINAL FOOD DATASET/"

# %%
import pandas as pd
import os



# List to hold the dataframes
dataframes = []

# Iterate over all the files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory, filename)
        # Read the CSV file and append to the list
        df = pd.read_csv(file_path)
        
        dataframes.append(df)

# Concatenate all dataframes in the list
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                    food  Caloric Value    Fat  \
# 0             0           0  margarine with yoghurt             88    9.8
# 1             1           1   sunflower seed butter             99    8.8
# 2             2           2            hazelnut oil            120   13.6
# 3             3           3       menhaden fish oil           1966  218.0
# 4             4           4      cod liver fish oil            123   13.6
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             1.9                   5.6                   2.0          0.073
# 1             0.7                   6.2                   1.6          3.700
# 2             1.0                  10.6                   1.4          0.000
# 3            66.3                  58.2                  74.5          0.000
# 4             3.1                   6.4                   3.1          0.000
#
# ...

# %%
len(combined_df)
# Out:
# 2395

# %%
combined_df.isna().sum()
# Out:
# Unnamed: 0.1            0
# Unnamed: 0              0
# food                    0
# Caloric Value           0
# Fat                     0
# Saturated Fats          0
# Monounsaturated Fats    0
# Polyunsaturated Fats    0
# Carbohydrates           0
# Sugars                  0
# Protein                 0
# Dietary Fiber           0
# Cholesterol             0
# Sodium                  0
# Water                   0
# Vitamin A               0
# Vitamin B1              0
# Vitamin B11             0
# Vitamin B12             0
# Vitamin B2              0
# Vitamin B3              0
# Vitamin B5              0
# Vitamin B6              0
# Vitamin C               0
# Vitamin D               0
# Vitamin E               0
# Vitamin K               0
# Calcium                 0
# Copper                  0
# Iron                    0
# Magnesium               0
# Manganese               0
# Phosphorus              0
# Potassium               0
# Selenium                0
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2395 entries, 0 to 2394
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0.1          2395 non-null   int64
#  1   Unnamed: 0            2395 non-null   int64
#  2   food                  2395 non-null   object
#  3   Caloric Value         2395 non-null   int64
#  4   Fat                   2395 non-null   float64
#  5   Saturated Fats        2395 non-null   float64
#  6   Monounsaturated Fats  2395 non-null   float64
#  7   Polyunsaturated Fats  2395 non-null   float64
#  8   Carbohydrates         2395 non-null   float64
#  9   Sugars                2395 non-null   float64
#  10  Protein               2395 non-null   float64
#  11  Dietary Fiber         2395 non-null   float64
#  12  Cholesterol           2395 non-null   float64
#  13  Sodium                2395 non-null   float64
# ...

# %%
combined_food=" ".join([i for i in combined_df.food.to_list()])

# %%
combined_food[:100]
# Out:
# 'margarine with yoghurt sunflower seed butter hazelnut oil menhaden fish oil cod liver fish oil sardi'

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(combined_food)

# %%
from collections import Counter

# %%
combined_food_items=[i for i in combined_food.split(" ") if i!="with"]

# %%
count=Counter(combined_food_items)

# %%
most_common_characteristic=count.most_common(10)

# %%
import pandas as pd
df = pd.DataFrame(most_common_characteristic, columns=['word', 'count'])

# %%
import seaborn as sns
# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='word', data=df, palette='viridis')

# Add titles and labels
plt.title('Top 10 Most Common Food Items')
plt.xlabel('Count')
plt.ylabel('Food Item')

# Show the plot
plt.show()

# %%
[str(i) for i in most_common_characteristic]
# Out:
# ["('cooked', 371)",
#  "('raw', 340)",
#  "('cheese', 111)",
#  "('chicken', 94)",
#  "('beef', 88)",
#  "('canned', 86)",
#  "('pork', 75)",
#  "('soup', 63)",
#  "('dried', 62)",
#  "('beans', 61)"]

# %% [markdown]
# ### word cloud for each ingredent food items

# %%
def create_word_cloud(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
filtered_df.head() # type: ignore
# Out:
#       Unnamed: 0.1  Unnamed: 0                              food  \
# 601            601         601       string beans wellsley farms
# 1029            75          75                burrito with beans
# 1040            86          86  enchirito with cheese beef beans
# 1054           100         100           burrito with beans beef
# 1076           122         122                 refried red beans
#
#       Caloric Value   Fat  Saturated Fats  Monounsaturated Fats  \
# 601               8   0.0             0.0                   0.0
# 1029            224   6.7             3.4                   2.4
# 1040            344  16.1             7.9                   6.5
# 1054            460  18.0             7.0                   7.8
# 1076            336  16.1             2.2                   3.9
#
#       Polyunsaturated Fats  Carbohydrates  Sugars  ...  Calcium  Copper  Iron  \
# 601                    0.0            1.7     0.3  ...      0.0     0.0   0.0
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2395 entries, 0 to 2394
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0.1          2395 non-null   int64
#  1   Unnamed: 0            2395 non-null   int64
#  2   food                  2395 non-null   object
#  3   Caloric Value         2395 non-null   int64
#  4   Fat                   2395 non-null   float64
#  5   Saturated Fats        2395 non-null   float64
#  6   Monounsaturated Fats  2395 non-null   float64
#  7   Polyunsaturated Fats  2395 non-null   float64
#  8   Carbohydrates         2395 non-null   float64
#  9   Sugars                2395 non-null   float64
#  10  Protein               2395 non-null   float64
#  11  Dietary Fiber         2395 non-null   float64
#  12  Cholesterol           2395 non-null   float64
#  13  Sodium                2395 non-null   float64
# ...

# %%
combined_df=combined_df.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1)

# %%
combined_df[:][:1]
# Out:
#                      food  Caloric Value  Fat  Saturated Fats  \
# 0  margarine with yoghurt             88  9.8             1.9
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   5.6                   2.0          0.073     0.0    0.058
#
#    Dietary Fiber  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# 0            0.0  ...      2.8   0.001  0.027        0.3        0.0
#
#    Phosphorus  Potassium  Selenium   Zinc  Nutrition Density
# 0         2.2        3.5       0.0  0.008             12.971
#
# [1 rows x 35 columns]

# %%
numeric_columns = ['Caloric Value', 'Fat', 'Saturated Fats', 'Monounsaturated Fats', 
                   'Polyunsaturated Fats', 'Carbohydrates', 'Sugars', 'Protein', 
                   'Dietary Fiber', 'Cholesterol', 'Sodium', 'Water', 'Vitamin A', 
                   'Vitamin B1', 'Vitamin B11', 'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 
                   'Vitamin B5', 'Vitamin B6', 'Vitamin C', 'Vitamin D', 'Vitamin E', 
                   'Vitamin K', 'Calcium', 'Copper', 'Iron', 'Magnesium', 'Manganese', 
                   'Phosphorus', 'Potassium', 'Selenium', 'Zinc', 'Nutrition Density']

# %% [markdown]
# ## Correlation Matrix

# %%
# Calculate the correlation matrix excluding non-numeric columns
correlation_matrix = combined_df[numeric_columns].corr()

# Plot the heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Hishest Correlation

# %%
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Apply the mask to the correlation matrix
corr_matrix_masked = correlation_matrix.mask(mask)

# Find the highest correlated pairs
highest_corr_pairs = corr_matrix_masked.unstack().dropna().sort_values(ascending=False).reset_index()

# %%
highest_corr_pairs.columns = ['Feature 1', 'Feature 2', 'Correlation']
highest_corr_pairs.head(10)
# Out:
#        Feature 1             Feature 2  Correlation
# 0            Fat  Monounsaturated Fats     0.924344
# 1  Caloric Value                   Fat     0.901783
# 2        Protein            Vitamin B3     0.876010
# 3        Protein            Phosphorus     0.873285
# 4     Vitamin B3            Phosphorus     0.859884
# 5      Manganese              Selenium     0.848944
# 6  Caloric Value  Monounsaturated Fats     0.845348
# 7     Phosphorus             Potassium     0.826714
# 8    Vitamin B12            Vitamin B2     0.817085
# 9        Calcium     Nutrition Density     0.796068

# %%
most_correlated_features = highest_corr_pairs.head(10)[['Feature 1', 'Feature 2']].values.flatten()

# Keep only the relevant columns for the most correlated features
corr_subset = correlation_matrix.loc[most_correlated_features, most_correlated_features]

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_subset, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Most Correlated Components Matrix')
plt.show()

# %%
len(list(combined_df.columns))
# Out:
# 35

# %%
len(set(combined_df.columns))
# Out:
# 35

# %% [markdown]
# ### Pairplot

# %%
subset = ['Caloric Value', 'Fat', 'Carbohydrates', 'Protein', 'Sugars']
sns.pairplot(combined_df[subset])
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Boxplots

# %%
# Boxplots of numeric columns
plt.figure(figsize=(20, 15))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(6, 6, i)
    sns.boxplot(y=combined_df[col])
    plt.title(col)
plt.tight_layout()
plt.suptitle('Boxplots of Numeric Features', y=1.02)
plt.show()

# %% [markdown]
# ## Nutritional Density Analysis

# %%
food_groups = combined_df.groupby('food').mean().reset_index()

# %%
# Top food items by nutritional density
top_nutrition_density_foods = food_groups.sort_values(by='Nutrition Density', ascending=False).head(10)
plt.figure(figsize=(12, 8))
sns.barplot(x='Nutrition Density', y='food', data=top_nutrition_density_foods, palette='viridis')
plt.title('Top 10 Food Items by Nutrition Density')
plt.show()
